# %% [markdown]
# <div align="center">
# <h1>Data, the New Best Friend of the Humanist<br/>*Bibliography*</h1>
# </div>

# %% [markdown]
# ## Student

# %% [markdown]
# Bibliography (Student)
# Baayen, R. Harald. Analyzing linguistic data: A practical introduction to statistics using R. Cambridge University Press, 2008.
#
# Bret Victor. Learnable Programming. Designing a programming system for understanding programs. September 2012. http://worrydream.com/LearnableProgramming
#
# Chomsky, N. 1956. Three models for the description of language. IRE Transactions on Information Theory (2): 113–124.
#
# Daley, Mark. Computer Science 2120/9642 Materials, 2013. https://dl.dropbox.com/u/8011180/2120/index.html
#
# Downey, Allen, Chris Meyers, and Jeffrey Elkner. How to think like a computer scientist. Green Tea Press, 1999. http://www.openbookproject.net/thinkcs/python/english2e/
#
# Friedl, J. 2006. Mastering regular expressions. O'Reilly Media, Incorporated, 2006.
#
# Gries, Stefan Th. Quantitative corpus linguistics with R: a practical introduction. Routledge, 2009.
#
# Jenset, Gard B. "Basic R for corpus linguistics."
#
# John M. Chambers and Trevor J. Hastie eds. (1992), Statistical Models in S. Chapman & Hall, New York. This is also called the “White Book ”.
#
# Knuth, Donald E.. (First Edition 1968). The Art of Computer Programming Second Edition, Volume 1/Fundamental Algorithms (2nd, 1973 ed.). Addison-Wesley Publishing Company.
#
# MacWhinney, Brian. The CHILDES Project: Tools for Analyzing Talk. Transcription, format and programs. Vol. 1. Lawrence Erlbaum, 2000.
#
# Papert, Seymour. Mindstorms: Children, computers, and powerful ideas. Basic Books, Inc., 1980.
#
# Pilgrim, Mark. Dive Into Python. Apress, 2004.
#
# Prakash B Pimpale. Natural Language Toolkit [NLTK] (CC 3.0 KBCS CDAC MUMBAI).
#
# Python Documentation, Python Software Foundation, 2013. http://docs.python.org/2/index.html
#
# R Development Core Team (2008). R: A Language and Environment for Statistical Computing. Vienna, Austria: R Foundation for Statistical Computing.
#
# Sokolov, Jeffrey L. & Snow, Catherine E. Transcript analysis using the Child Language Data Exchange System. In J.L. Sokolov & C.E. Snow (eds.) 1994: 1-25.
#
# Sokolov, Jeffrey L., and Catherine E. Snow, eds. Handbook of research in language development using CHILDES. L. Erlbaum Associates, 1994.
#
# Spector, P. (2008). Data manipulation with R. New York: Springer.
#
# Steven Bird, Ewan Klein, and Edward Loper. Natural Language Processing with Python, Analyzing Text with the Natural Language Toolkit. O'Reilly Media, 2009
#
# Venables, Bill, et al. "Notes on R. A Programming Environment for Data Analysis and Graphics." (1997).
#
# Venables, W., D. Smith, and the R Development Core Team (2004). An introduction to R: Revised and updated. Bristol: Network Theory.
#
# Walker. R. 2012. Regular Expressions Will Stab You in the Back. http://tech.cueup.com/blog/2012/10/26/regular-expressions-will-stab-you-in-the-back/

# %% [markdown]
# ## Professor

# %% [markdown]
# John L. Hennessy and David A. Patterson. 2011. Computer Architecture: A Quantitative Approach.
#
# Abelson, H., & Sussman, G. J. (1983). Structure and interpretation of computer programs.
#
# Baayen, R. Harald. Analyzing linguistic data: A practical introduction to statistics using R. Cambridge University Press, 2008.
#
# Bic, Lubomur F.; Shaw, Alan C. (2003). Operating Systems. Pearson: Prentice Hall.
#
# Bresnan, J., Cueni, A., Nikitina, T. and Baayen, R. H. (2007) Predicting the dative alternation, in Bouma, G. and Kraemer, I. and Zwarts, J.  (eds.), Cognitive Foundations of Interpretation, Royal Netherlands Academy of Sciences, 33 pages, in press.
#
# Bret Victor. Learnable Programming. Designing a programming system for understanding programs. September 2012. http://worrydream.com/LearnableProgramming
#
# Chomsky, N. 1956. Three models for the description of language. IRE Transactions on Information Theory (2): 113–124.
#
# Christopher Burns et al. Python Scientific Lecture Notes. 2013. http://scipy-lectures.github.com/
#
# D. Harel. Algorithmics: The Spirit of Computing. Addison-Wesley, 2nd edition, 1992.
#
# Daley, Mark. Computer Science 2120/9642 Materials, 2013. https://dl.dropbox.com/u/8011180/2120/index.html
#
# Dean Sanders and Brian Dorn (2004). Introduction to Jeroo, Version 2.4. Northwest Missouri State University.
#
# Downey, Allen, Chris Meyers, and Jeffrey Elkner. How to think like a computer scientist. Green Tea Press, 1999. http://www.openbookproject.net/thinkcs/python/english2e/
#
# Eilenberg, S. 1974. Automata, Languages, and Machines. A. New York: Academic Press.
#
# Friedl, J. 2006. Mastering regular expressions. O'Reilly Media, Incorporated, 2006.
#
# Gimpel, J. F. 1973. A theory of discrete patterns and their implementation in SNOBOL4. Commun. ACM 16, 2 (Feb. 1973), 91-100.
#
# Gries, Stefan Th. Quantitative corpus linguistics with R: a practical introduction. Routledge, 2009.
#
# Guido Van Rossum. Python Workshop (ACM@UIUC), 1999.
#
# Hopcroft, J. E.; Motwani,R; Ullman, J.D. 2001. Introduction to Automata Theory, Languages, and Computation (2 ed.). Addison Wesley. ISBN 0-201-44124-1.
#
# Jenset, Gard B. "Basic R for corpus linguistics."
#
# John M. Chambers (1998) Programming with Data. Springer, New York. This is also called the “Green Book ”.
#
# John M. Chambers and Trevor J. Hastie eds. (1992), Statistical Models in S. Chapman & Hall, New York. This is also called the “White Book ”.
#
# Jonathan Bartlett: Programming from the Ground Up. Bartlett Publishing, 2004.
#
# Knuth, Donald E.. (First Edition 1968). The Art of Computer Programming Second Edition, Volume 1/Fundamental Algorithms (2nd, 1973 ed.). Addison-Wesley Publishing Company.
#
# Kuchling A.M. 2012. Regular Expressions HOWTO. Python Foundation. http://docs.python.org/2/howto/regex.html#regex-howto
#
# M. Morris Mano (19-10-1992). Computer System Architecture. Prentice Hall
#
# MacWhinney, Brian. The CHILDES Project: Tools for Analyzing Talk. Transcription, format and programs. Vol. 1. Lawrence Erlbaum, 2000.
#
# Navarro, G. 2001. A guided tour to approximate string matching. ACM Computing Surveys 33 (1): 31–88.
#
# Nørmark, Kurt. Overview of the four main programming paradigms. Aalborg University, 9 May 2011. Retrieved 22 September 2012.
#
# Papert, Seymour. Mindstorms: Children, computers, and powerful ideas. Basic Books, Inc., 1980.
#
# Paul S. Rosenbloom. 2012. On Computing: The Fourth Great Scientific Domain.
#
# PC Hardware in a Nutshell by Robert Bruce Thompson and Barbara Fritchman Thompson (Jul 31 2003)
#
# Pilgrim, Mark. Dive Into Python. Apress, 2004.
#
# Prakash B Pimpale. Natural Language Toolkit [NLTK] (CC 3.0 KBCS CDAC MUMBAI).
#
# Python Documentation, Python Software Foundation, 2013. http://docs.python.org/2/index.html
#
# R Development Core Team (2008). R: A Language and Environment for Statistical Computing. Vienna, Austria: R Foundation for Statistical Computing.
#
# Richard A. Becker, John M. Chambers and Allan R. Wilks (1988), The New S Language. Chapman & Hall, New York. This book is often called the “Blue Book ”.
#
# Sokolov, Jeffrey L. & Snow, Catherine E. Transcript analysis using the Child Language Data Exchange System. In J.L. Sokolov & C.E. Snow (eds.) 1994: 1-25.
#
# Sokolov, Jeffrey L., and Catherine E. Snow, eds. Handbook of research in language development using CHILDES. L. Erlbaum Associates, 1994.
#
# Spector, P. (2008). Data manipulation with R. New York: Springer.
#
# Steven Bird, Ewan Klein, and Edward Loper. Natural Language Processing with Python, Analyzing Text with the Natural Language Toolkit. O'Reilly Media, 2009
#
# Stokes, Jon. 2007. Inside the Machine: An Illustrated Introduction to Microprocessors and Computer Architecture. San Francisco: No Starch Press.
#
# The Essential Guide to Computing: The Story of Information Technology by E. Garrison Walters (Aug 1 2000)
#
# The Undocumented PC: A Programmer's Guide to I/O, CPUs, and Fixed Memory Areas by Frank van Gilluwe (Dec 23 1996)
#
# Thomas H. Cormen, Charles E. Leiserson, Ronald L. Rivest, and Clifford Stein. Introduction to Algorithms, Second Edition. MIT Press and McGraw-Hill, 2001.
#
# Van Rossum, Guido. An introduction to Python. Ed. Fred L. Drake. Network Theory Ltd., 2003.
#
# Venables, Bill, et al. "Notes on R. A Programming Environment for Data Analysis and Graphics." (1997).
#
# Venables, W., D. Smith, and the R Development Core Team (2004). An introduction to R: Revised and updated. Bristol: Network Theory.
#
# Walker. R. 2012. Regular Expressions Will Stab You in the Back. http://tech.cueup.com/blog/2012/10/26/regular-expressions-will-stab-you-in-the-back/
