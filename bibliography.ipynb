# %% [markdown]
# <div align="center">
# <h1>[Data, the Humanist's New Best Friend](index.ipynb)<br/>*Bibliography*</h1>
# </div>

# %% [markdown]
# ## Student

# %% [markdown]
# ### Programming and Python
#
# * Bret Victor. Learnable Programming. Designing a programming system for understanding programs. September 2012. http://worrydream.com/LearnableProgramming
#
# * Daley, Mark. Computer Science 2120/9642 Materials, 2013. https://dl.dropbox.com/u/8011180/2120/index.html
#
# * Downey, Allen, Chris Meyers, and Jeffrey Elkner. How to think like a computer scientist. Green Tea Press, 1999. http://www.openbookproject.net/thinkcs/python/english3e/
#
# * Papert, Seymour. Mindstorms: Children, computers, and powerful ideas. Basic Books, Inc., 1980.
#
#
# ### Data Mining
#
# * Christopher Burns et al. Python Scientific Lecture Notes. 2013. http://scipy-lectures.github.com/
#
# * Daumé III, Hal (2014) A Course in Machine Learning. http://ciml.info/
#
# * McKinney, Wes. Python for Data Analysis: Data Wrangling with Pandas, NumPy, and IPython. O'Reilly Media, 2012.
#
# ### Text Analysis
#
# * Steven Bird, Ewan Klein, and Edward Loper. Natural Language Processing with Python, Analyzing Text with the Natural Language Toolkit. O'Reilly Media, 2009.
#
# * Walker. R. 2012. Regular Expressions Will Stab You in the Back. http://tech.cueup.com/blog/2012/10/26/regular-expressions-will-stab-you-in-the-back/
#
#
# ### Network Science
# * Easley, David, and Jon Kleinberg. "Networks, crowds, and markets." Cambridge Univ Press 6.1 (2010): 6-1.
#
# * Moretti, Franco (2011) Graphs, Maps, Trees: Abstract Models for a Literary History Hardcover by
# http://www.amazon.com/dp/1844670260/?tag=stackoverfl08-20
#
# * Robinson, Ian; Jim Webber, and Emil Eifrém. Graph Databases, O'Reilly, 2013.
#
# * Tsvetovat, Maksim, and Alexander Kouznetsov. Social Network Analysis for Startups: Finding connections on the social web. O'Reilly Media, 2011.

# %% [markdown]
# ## Professor

# %% [markdown]
# ### Programming and Python
#
# * Abelson, H., & Sussman, G. J. (1983). Structure and interpretation of computer programs.
#
# * Bret Victor. Learnable Programming. Designing a programming system for understanding programs. September 2012. http://worrydream.com/LearnableProgramming
#
# * Daley, Mark. Computer Science 2120/9642 Materials, 2013. https://dl.dropbox.com/u/8011180/2120/index.html
#
# * Downey, Allen, Chris Meyers, and Jeffrey Elkner. How to think like a computer scientist. Green Tea Press, 1999. http://www.openbookproject.net/thinkcs/python/english3e/
#
# * John L. Hennessy and David A. Patterson. 2011. Computer Architecture: A Quantitative Approach.
#
# * Papert, Seymour. Mindstorms: Children, computers, and powerful ideas. Basic Books, Inc., 1980.
#
# * Pilgrim, Mark. Dive Into Python. Apress, 2004.
#
# * Python Documentation, Python Software Foundation, 2013. http://docs.python.org/3/index.html
#
# * Knuth, Donald E.. (First Edition 1968). The Art of Computer Programming Second Edition, Volume 1/Fundamental Algorithms (2nd, 1973 ed.). Addison-Wesley Publishing Company.
#
# * D. Harel. Algorithmics: The Spirit of Computing. Addison-Wesley, 2nd edition, 1992.
#
# ### Data Mining
#
# * Alpaydin, Ethem. Introduction to machine learning. MIT press, 2004.
#
# * Bishop, Christopher M. Pattern recognition and machine learning. Vol. 1. New York: springer, 2006.
#
# * Canning, John (2014) Statistics for Humanities. http://statisticsforhumanities.net/
#
# * Christopher Burns et al. Python Scientific Lecture Notes. 2013. http://scipy-lectures.github.com/
#
# * Daumé III, Hal (2014) A Course in Machine Learning. http://ciml.info/
#
# * Hastie, Trevor, et al. The elements of statistical learning. Vol. 2. No. 1. New York: Springer, 2009.
#
# * John M. Chambers (1998) Programming with Data. Springer, New York. This is also called the “Green Book ”.
#
# * Langtangen, Hans Petter. Python scripting for computational science. Vol. 3. Berlin, Heidelberg and New York: Springer, 2006.
#
# * Pedregosa, Fabian, et al. "Scikit-learn: Machine learning in Python." The Journal of Machine Learning Research 12 (2011): 2825-2830.
#
# * McKinney, Wes. Python for Data Analysis: Data Wrangling with Pandas, NumPy, and IPython. O'Reilly Media, 2012.
#
# * Spector, P. (2008). Data manipulation with R. New York: Springer.
#
# * Wickham, Hadley. "The split-apply-combine strategy for data analysis." Journal of Statistical Software 40.1 (2011): 1-29.
#
# ### Text Analysis
#
# * Friedl, J. 2006. Mastering regular expressions. O'Reilly Media, Incorporated, 2006.
#
# * Gries, Stefan Th. Quantitative corpus linguistics with R: a practical introduction. Routledge, 2009.
#
# * Kuchling A.M. 2012. Regular Expressions HOWTO. Python Foundation. http://docs.python.org/2/howto/regex.html#regex-howto
#
# * Prakash B Pimpale. Natural Language Toolkit [NLTK] (CC 3.0 KBCS CDAC MUMBAI).
#
# * Russell, Matthew A. Mining the Social Web: Data Mining Facebook, Twitter, LinkedIn, Google+, GitHub, and More. " O'Reilly Media, Inc.", 2013.
#
# * Steven Bird, Ewan Klein, and Edward Loper. Natural Language Processing with Python, Analyzing Text with the Natural Language Toolkit. O'Reilly Media, 2009
#
# * Walker. R. 2012. Regular Expressions Will Stab You in the Back. http://tech.cueup.com/blog/2012/10/26/regular-expressions-will-stab-you-in-the-back/
#
#
# ### Network Science
#
# * Dasgupta, Sanjoy, Christos H. Papadimitriou, and Umesh Vazirani. Algorithms. McGraw-Hill, Inc., 2006.
#
# * Easley, David, and Jon Kleinberg. "Networks, crowds, and markets." Cambridge Univ Press 6.1 (2010): 6-1.
#
# * Moretti, Franco (2011) Graphs, Maps, Trees: Abstract Models for a Literary History Hardcover
# http://www.amazon.com/dp/1844670260/?tag=stackoverfl08-20
#
# * Python for Social Science.
#  http://www-rohan.sdsu.edu/~gawron/python_for_ss/course_core/book_draft/Social_Networks
#
# * Robinson, Ian; Jim Webber, and Emil Eifrém. Graph Databases, O'Reilly, 2013.
#
# * Tsvetovat, Maksim, and Alexander Kouznetsov. Social Network Analysis for Startups: Finding connections on the social web. O'Reilly Media, 2011.
